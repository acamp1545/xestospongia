# %%
# !qiime metadata validate --input-file xesto454_metadata_new.tsv

# %%
# !qiime tools import --type 'SampleData[SequencesWithQuality]' --input-path xesto_454manifest_noreseq.tsv --input-format SingleEndFastqManifestPhred33V2 --output-path seqs.qza
# Out:
# 2154.15s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Imported xesto_454manifest_noreseq.tsv as SingleEndFastqManifestPhred33V2 to seqs.qza

# %%
# !qiime metadata tabulate --m-input-file xesto454_metadata_new.tsv --o-visualization tabulated-xestospongia454-metadata.qzv
# Out:
# 3003.98s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /Users/alexandracampbell/miniconda3/envs/q2-amp2024.10/lib/python3.10/site-packages/qiime2/metadata/io.py:365: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   series = series.replace('', np.nan).infer_objects(copy=False)
# Saved Visualization to: tabulated-xestospongia454-metadata.qzv

# %%
# !unzip tabulated-xestospongia-metadata.qzv

# %%
# !mkdir xesto_reads
# Out:
# 3114.99s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
# !qiime dada2 denoise-pyro --i-demultiplexed-seqs xesto_reads/seqs.qza --p-trunc-len 280 --p-chimera-method consensus --output-dir xesto_reads/denoise --verbose
# Out:
# 3170.99s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada.R --input_directory /var/folders/4g/f6nbk69j0z1d3vly0v9t1hn40000gn/T/qiime2/alexandracampbell/data/d6464753-4aaf-455a-8324-754b028d0cc4/data --output_path /var/folders/4g/f6nbk69j0z1d3vly0v9t1hn40000gn/T/tmp3teydl3t/output.tsv.biom --output_track /var/folders/4g/f6nbk69j0z1d3vly0v9t1hn40000gn/T/tmp3teydl3t/track.tsv --filtered_directory /var/folders/4g/f6nbk69j0z1d3vly0v9t1hn40000gn/T/tmp3teydl3t --truncation_length 280 --trim_left 0 --max_expected_errors 2.0 --truncation_quality_score 2 --max_length Inf --pooling_method independent --chimera_method consensus --min_parental_fold 1.0 --allow_one_off False --num_threads 1 --learn_min_reads 250000 --homopolymer_gap_penalty 1 --band_size 32
#
# R version 4.3.3 (2024-02-29)
# Loading required package: Rcpp
# DADA2: 1.30.0 / Rcpp: 1.0.13.1 / RcppParallel: 5.1.9
# ...................................................
# 3) Learning Error Rates
# 72609880 total bases in 259321 reads from 51 samples will be used for learning the error rates.
# 4) Denoise samples
# ...................................................
# 5) Remove chimeras (method = consensus)
# 6) Report read numbers through the pipeline
# 7) Write output
# Saved FeatureTable[Frequency] to: xesto_reads/denoise/table.qza
# Saved FeatureData[Sequence] to: xesto_reads/denoise/representative_sequences.qza
# Saved SampleData[DADA2Stats] to: xesto_reads/denoise/denoising_stats.qza

# %%
# !qiime tools export --input-path xesto_reads/denoise/denoising_stats.qza --output-path xesto-dada2-output-454
# Out:
# 4379.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Exported xesto_reads/denoise/denoising_stats.qza as DADA2StatsDirFmt to directory xesto-dada2-output-454

# %%
# !qiime feature-table summarize --i-table xesto_reads/denoise/table.qza --o-visualization xesto-dada2-output-454/stats.tsv --m-sample-metadata-file xesto454_metadata_new.tsv
# Out:
# 4815.81s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /Users/alexandracampbell/miniconda3/envs/q2-amp2024.10/lib/python3.10/site-packages/qiime2/metadata/io.py:365: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   series = series.replace('', np.nan).infer_objects(copy=False)
# Saved Visualization to: xesto-dada2-output-454/stats.tsv.qzv

# %%
# !qiime feature-table tabulate-seqs --i-data xesto_reads/denoise/representative_sequences.qza --o-visualization xesto-454-rep-seqs.qzv
# Out:
# 4847.42s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Saved Visualization to: xesto-454-rep-seqs.qzv

# %%
# !unzip xesto-dada2-output-454/stats.tsv.qzv
# Out:
# 4973.66s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Archive:  xesto-dada2-output-454/stats.tsv.qzv
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/metadata.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/checksums.md5
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/VERSION
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/metadata.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/citations.bib
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/VERSION
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/metadata.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/citations.bib
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/VERSION
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/action/action.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/metadata.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/citations.bib
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/VERSION
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/action/action.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/action/action.yaml
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/provenance/action/sample_metadata.tsv
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/util.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/sample-frequency-detail.html
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/index.html
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/sample-frequencies.png
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/sample-frequencies.pdf
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/feature-frequency-detail.html
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/feature-frequencies.pdf
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/feature-frequencies.png
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/licenses/vega.txt
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/licenses/vega-embed.txt
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/css/spinkit.css
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/js/vega.min.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/js/vega-embed.min.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/css/bootstrap.min.css
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/css/base-template.css
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/css/tab-parent.css
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/css/normalize.css
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/js/parent.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/js/bootstrap.min.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/js/jquery-3.2.0.min.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/js/child.js
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/img/qiime2-rect-200.png
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/fonts/glyphicons-halflings-regular.woff
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/fonts/glyphicons-halflings-regular.eot
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/fonts/glyphicons-halflings-regular.woff2
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/fonts/glyphicons-halflings-regular.ttf
#   inflating: b7c63eb0-53fd-4638-8f70-58bb79ab021f/data/q2templateassets/fonts/glyphicons-halflings-regular.svg

# %%
# !unzip xesto-454-rep-seqs.qzv
# Out:
# 4978.93s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Archive:  xesto-454-rep-seqs.qzv
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/metadata.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/checksums.md5
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/VERSION
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/metadata.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/citations.bib
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/VERSION
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/f7b8fcae-d871-488c-874a-7a3205275b31/metadata.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/f7b8fcae-d871-488c-874a-7a3205275b31/citations.bib
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/f7b8fcae-d871-488c-874a-7a3205275b31/VERSION
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/f7b8fcae-d871-488c-874a-7a3205275b31/action/action.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/metadata.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/citations.bib
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/VERSION
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/action/action.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/provenance/action/action.yaml
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/index.html
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/seven_number_summary.tsv
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/sequences.fasta
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/descriptive_stats.tsv
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/js/tsorter.min.js
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/css/bootstrap.min.css
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/css/base-template.css
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/css/tab-parent.css
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/css/normalize.css
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/js/parent.js
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/js/bootstrap.min.js
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/js/jquery-3.2.0.min.js
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/js/child.js
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/img/qiime2-rect-200.png
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/fonts/glyphicons-halflings-regular.woff
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/fonts/glyphicons-halflings-regular.eot
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/fonts/glyphicons-halflings-regular.woff2
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/fonts/glyphicons-halflings-regular.ttf
#   inflating: 53857c4d-bfe2-4fa2-bf11-f5b2e332b620/data/q2templateassets/fonts/glyphicons-halflings-regular.svg

# %%
# !qiime metadata tabulate \
  --m-input-file xesto_reads/denoise/denoising_stats.qza \
  --o-visualization xesto_reads/denoise/stats.qzv
# Out:
# 5057.35s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Saved Visualization to: xesto_reads/denoise/stats.qzv

# %%
# !unzip xesto_reads/denoise/stats.qzv
# Out:
# 5079.47s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Archive:  xesto_reads/denoise/stats.qzv
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/metadata.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/checksums.md5
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/VERSION
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/metadata.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/citations.bib
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/VERSION
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/6a128a27-c005-415b-baff-b0ddceded2f2/metadata.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/6a128a27-c005-415b-baff-b0ddceded2f2/citations.bib
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/6a128a27-c005-415b-baff-b0ddceded2f2/VERSION
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/6a128a27-c005-415b-baff-b0ddceded2f2/action/action.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/metadata.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/citations.bib
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/VERSION
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/action/action.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/action/action.yaml
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/provenance/action/input.tsv
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/index.html
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/metadata.tsv
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/css/datatables.min.css
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/js/datatables.min.js
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/css/bootstrap.min.css
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/css/base-template.css
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/css/tab-parent.css
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/css/normalize.css
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/js/parent.js
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/js/bootstrap.min.js
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/js/jquery-3.2.0.min.js
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/js/child.js
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/img/qiime2-rect-200.png
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/fonts/glyphicons-halflings-regular.woff
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/fonts/glyphicons-halflings-regular.eot
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/fonts/glyphicons-halflings-regular.woff2
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/fonts/glyphicons-halflings-regular.ttf
#   inflating: 1be870dc-f926-4dcd-850e-082b5322c061/data/q2templateassets/fonts/glyphicons-halflings-regular.svg

# %%
# !qiime feature-classifier fit-classifier-naive-bayes --i-reference-reads silva-138-99-seqs-515-806.qza --i-reference-taxonomy silva-138-99-tax-515-806.qza --o-classifier s138_v2_classifier.qza
# Out:
# 5954.67s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Saved TaxonomicClassifier to: s138_v2_classifier.qza

# %%
# !qiime feature-classifier classify-sklearn --i-classifier s138_v2_classifier.qza --i-reads xesto_reads/denoise/representative_sequences.qza --o-classification xesto_reads/xesto_454_taxonomy.qza
# Out:
# 7557.09s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Saved FeatureData[Taxonomy] to: xesto_reads/xesto_454_taxonomy.qza

# %%
# !mkdir phyloseq
# Out:
# 8322.15s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
# !qiime tools export --input-path xesto_reads/denoise/table.qza --output-path phyloseq
# Out:
# 8334.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Exported xesto_reads/denoise/table.qza as BIOMV210DirFmt to directory phyloseq

# %%
# !biom convert -i phyloseq/feature-table.biom -o phyloseq/otu_table.txt --to-tsv
# Out:
# 8437.60s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
# !qiime tools export --input-path xesto_reads/xesto_454_taxonomy.qza --output-path phyloseq
# Out:
# 8580.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Exported xesto_reads/xesto_454_taxonomy.qza as TSVTaxonomyDirectoryFormat to directory phyloseq

# %%
# !qiime phylogeny align-to-tree-mafft-fasttree --i-sequences xesto_reads/denoise/representative_sequences.qza --o-alignment xesto_reads/aligned-rep-seqs.qza --o-masked-alignment xesto_reads/masked-alignment.qza --o-tree xesto_reads/unrooted-tree.qza --o-rooted-tree xesto_reads/rooted-tree.qza
# Out:
# 8612.85s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Saved FeatureData[AlignedSequence] to: xesto_reads/aligned-rep-seqs.qza
# Saved FeatureData[AlignedSequence] to: xesto_reads/masked-alignment.qza
# Saved Phylogeny[Unrooted] to: xesto_reads/unrooted-tree.qza
# Saved Phylogeny[Rooted] to: xesto_reads/rooted-tree.qza

# %%
# !qiime diversity alpha-phylogenetic --i-table xesto_reads/denoise/table.qza --i-phylogeny xesto_reads/rooted-tree.qza --p-metric faith_pd --o-alpha-diversity faith_pd_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: faith_pd_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric observed_features --o-alpha-diversity obs_feat_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: obs_feat_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric ace --o-alpha-diversity ace_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: ace_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric shannon --o-alpha-diversity shannon_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: shannon_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric simpson --o-alpha-diversity simpson_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: simpson_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric michaelis_menten_fit --o-alpha-diversity MM_fit_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: MM_fit_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric chao1 --o-alpha-diversity chao1_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: chao1_vector.qza

# %%
# !qiime diversity alpha --i-table xesto_reads/denoise/table.qza --p-metric fisher_alpha --o-alpha-diversity fisher_alpha_vector.qza
# Out:
# Saved SampleData[AlphaDiversity] to: fisher_alpha_vector.qza

# %%
# !qiime diversity beta --i-table xesto_reads/denoise/table.qza --p-metric braycurtis --o-distance-matrix braycurtis_distance_matrix.qza
# Out:
# Saved DistanceMatrix to: braycurtis_distance_matrix.qza

# %%
# !qiime diversity beta --i-table xesto_reads/denoise/table.qza --p-metric euclidean --o-distance-matrix euclidean_distance_matrix.qza
# Out:
# Saved DistanceMatrix to: euclidean_distance_matrix.qza

# %%
# !qiime diversity beta-phylogenetic --i-table xesto_reads/denoise/table.qza --i-phylogeny xesto_reads/rooted-tree.qza --p-metric generalized_unifrac --o-distance-matrix gen_unifrac_distance_matrix.qza
# Out:
# Saved DistanceMatrix to: gen_unifrac_distance_matrix.qza

# %%
# !unzip diversityfromq2/ace_vector.qza

# %%
# !unzip diversityfromq2/shannon_vector.qza
# Out:
# Archive:  diversityfromq2/shannon_vector.qza
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/metadata.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/checksums.md5
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/VERSION
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/metadata.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/citations.bib
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/VERSION
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/cb12b6ad-2533-4753-8be5-eec1bc1a63ea/metadata.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/cb12b6ad-2533-4753-8be5-eec1bc1a63ea/citations.bib
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/cb12b6ad-2533-4753-8be5-eec1bc1a63ea/VERSION
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/cb12b6ad-2533-4753-8be5-eec1bc1a63ea/action/action.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/metadata.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/citations.bib
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/VERSION
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/action/action.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/metadata.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/citations.bib
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/VERSION
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/action/action.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/provenance/action/action.yaml
#   inflating: 44bd95e7-9b9b-43f7-9cec-50048c6176fe/data/alpha-diversity.tsv

# %%
# !unzip diversityfromq2/obs_feat_vector.qza
# Out:
# Archive:  diversityfromq2/obs_feat_vector.qza
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/metadata.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/checksums.md5
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/VERSION
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/metadata.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/citations.bib
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/VERSION
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/1a7def12-fe74-4cb4-a190-d5e4b5fa5938/metadata.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/1a7def12-fe74-4cb4-a190-d5e4b5fa5938/citations.bib
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/1a7def12-fe74-4cb4-a190-d5e4b5fa5938/VERSION
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/1a7def12-fe74-4cb4-a190-d5e4b5fa5938/action/action.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/metadata.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/citations.bib
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/VERSION
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/action/action.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/metadata.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/citations.bib
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/VERSION
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/action/action.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/provenance/action/action.yaml
#   inflating: 91265da9-b076-4f05-8f82-ecb93cd40f24/data/alpha-diversity.tsv

# %%
# !unzip diversityfromq2/simpson_vector.qza
# Out:
# Archive:  diversityfromq2/simpson_vector.qza
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/metadata.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/checksums.md5
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/VERSION
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/metadata.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/citations.bib
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/VERSION
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/metadata.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/citations.bib
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/VERSION
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d65fd7bc-823e-4af7-9edb-1440a6fb6a99/action/action.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/4caeedcd-3dc1-458c-b066-4b49a7dc55e0/metadata.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/4caeedcd-3dc1-458c-b066-4b49a7dc55e0/citations.bib
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/4caeedcd-3dc1-458c-b066-4b49a7dc55e0/VERSION
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/4caeedcd-3dc1-458c-b066-4b49a7dc55e0/action/action.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/metadata.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/citations.bib
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/VERSION
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745/provenance/artifacts/d6464753-4aaf-455a-8324-754b028d0cc4/action/action.yaml
#   inflating: 6161d13f-f71c-40c8-9300-26f29520d745